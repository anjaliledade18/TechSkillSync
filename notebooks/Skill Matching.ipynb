# %% [markdown]
# Modules

# %%
import pandas as pd
from rapidfuzz import fuzz, process  # Fuzzy matching for flexibility
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from nltk.corpus import wordnet
from nltk import pos_tag
from tabulate import tabulate  # Optional: required for better formatting

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Download all necessary NLTK resources
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger_eng')  # NEW - required for POS tagging

# Initialize lemmatizer and stopword list
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nick_\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\nick_\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nick_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\nick_\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Important Functions

# %%
# Helper to convert NLTK POS to WordNet POS
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # fallback

# Updated preprocess_text function
def preprocess_text(text):
    if not isinstance(text, str):
        return ""

    words = text.lower().split()
    words = [word for word in words if word not in stop_words]
    tagged_words = pos_tag(words)

    lemmatized_words = []
    for word, pos in tagged_words:
        wn_pos = get_wordnet_pos(pos)
        lemma = lemmatizer.lemmatize(word, wn_pos)
        if lemma == word and wn_pos != wordnet.VERB:
            # Retry as verb if unchanged
            lemma = lemmatizer.lemmatize(word, pos='v')
        lemmatized_words.append(lemma)

    return " ".join(lemmatized_words)

def remove_bracketed_words(text):
    if not isinstance(text, str):
        return ""
    
    # Remove all content inside brackets (including brackets)
    cleaned_text = re.sub(r'\s*\([^)]*\)', '', text).strip()
    
    return cleaned_text


# Function to find synonyms using WordNet
def get_synonyms(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name().replace("_", " "))  # Convert underscores to spaces
    return list(synonyms)

def print_pretty_table(df):
    print("\n📋 Matched Jobs with Alternative Titles")
    print(tabulate(df, headers='keys', tablefmt='github', showindex=False))

# %% [markdown]
# Flattening the ESCO Data Set

# %%
# Load the dataset
file_path = "../data/ESCO skill taxonomy dataset.csv"
df = pd.read_csv(file_path)

# Columns containing skills
skill_columns = [
    "Essential Skills (Skill)",
    "Essential Skills (Knowledge)",
    "Optional Skills (Skill)",
    "Optional Skills (Knowledge)"
]

# Ensure missing values are handled
df[skill_columns] = df[skill_columns].fillna("")

# Split comma-separated skills into lists
for col in skill_columns:
    df[col] = df[col].apply(lambda x: x.split(", ") if isinstance(x, str) else [])

# Explode each skill column separately and merge back
esco_taxonomy_df = df.copy()
for col in skill_columns:
    esco_taxonomy_df = esco_taxonomy_df.explode(col)

# Rename columns for clarity
esco_taxonomy_df = esco_taxonomy_df.rename(columns={
    "Occupation Title": "Job Role",
    "ESCO Code": "ESCO Code",
    "Description": "Job Description",
    "Alternative Labels": "Alternative Titles",
    "Essential Skills (Skill)": "Essential Skill",
    "Essential Skills (Knowledge)": "Essential Knowledge",
    "Optional Skills (Skill)": "Optional Skill",
    "Optional Skills (Knowledge)": "Optional Knowledge"
})

# %%
columns_to_preprocess = [
    "Essential Skill",
    "Essential Knowledge",
    "Optional Skill",
    "Optional Knowledge"
]

for col in columns_to_preprocess:
    unique_values = esco_taxonomy_df[col].dropna().unique()
    processed_map = {val: preprocess_text(val) for val in unique_values}
    esco_taxonomy_df[col] = esco_taxonomy_df[col].map(processed_map)

esco_taxonomy_df["Essential Skill"] = esco_taxonomy_df["Essential Skill"].apply(remove_bracketed_words)
esco_taxonomy_df["Essential Knowledge"] = esco_taxonomy_df["Essential Knowledge"].apply(remove_bracketed_words)
esco_taxonomy_df["Optional Skill"] = esco_taxonomy_df["Optional Skill"].apply(remove_bracketed_words)
esco_taxonomy_df["Optional Knowledge"] = esco_taxonomy_df["Optional Knowledge"].apply(remove_bracketed_words)

# %% [markdown]
# Matching skills to jobs

# %%
# Create a set of all valid skills for fuzzy matching
all_skills = set(
    esco_taxonomy_df["Essential Skill"].dropna().tolist() +
    esco_taxonomy_df["Essential Knowledge"].dropna().tolist() +
    esco_taxonomy_df["Optional Skill"].dropna().tolist() +
    esco_taxonomy_df["Optional Knowledge"].dropna().tolist()
)

essential_skills = set(    
    esco_taxonomy_df["Essential Skill"].dropna().tolist() +
    esco_taxonomy_df["Essential Knowledge"].dropna().tolist()
    )

optional_skills = set(    
    esco_taxonomy_df["Optional Skill"].dropna().tolist() +
    esco_taxonomy_df["Optional Knowledge"].dropna().tolist()
)

# %%
file_path = "../data/tools_grouped.csv"

# Load Technology Tool Mapping
tech_tools_df = pd.read_csv(file_path)  # File containing tool-category mappings
tool_to_category = {}

for _, row in tech_tools_df.iterrows():
    raw_category = row["Technology Tool"]
    raw_tools = row["Technology Tool Example"].split(", ")

    # Preprocess the category name once
    category = preprocess_text(raw_category)

    for tool in raw_tools:
        preprocessed_tool = preprocess_text(tool)
        tool_to_category[preprocessed_tool] = category

# %% [markdown]
# This code performs intelligent matching between user-entered skills and job roles in the ESCO taxonomy, using a combination of fuzzy string matching and tool-category mapping. The map_skills_to_matched_tools() function takes an individual skill and tries to match it either directly to a known tool name or to a broader tool category using fuzzy matching (with a configurable similarity threshold). It returns the best-matching tool category based on score comparisons. The main function, match_jobs(), processes a list of user-input skills by first cleaning them and then attempting to match each one — prioritizing exact matches for short single-character skills (like "R"), followed by fuzzy matches against tools and the ESCO skills dataset. Top matches are selected based on similarity scores, and low-confidence or ambiguous matches are filtered out. Once the matching is done, the function aggregates all matched skills and compares them against job roles in the ESCO taxonomy by constructing a set of all skills (essential and optional) associated with each job. It counts how many matched user skills appear in each job's skill set, filters out roles with fewer than two matches, and returns a ranked list of job roles based on how well they align with the user’s skills. The output includes the number of overlapping skills per job and displays the best-matching roles for easier interpretation.

# %%
def map_skills_to_matched_tools(skill, threshold=85):
    """
    Matches user-entered skill to either a tool or tool category based on fuzzy score.
    Returns the best-matched tool category.
    """
    tool_names = list(tool_to_category.keys())
    tool_categories = list(set(tool_to_category.values()))
    skill_lower = preprocess_text(skill)

    # Fuzzy match with tool names
    match_result_tool = process.extractOne(skill_lower, tool_names, scorer=fuzz.WRatio)
    tool_match, tool_score = match_result_tool[:2] if match_result_tool else (None, 0)
    tool_category = tool_to_category.get(tool_match) if tool_match else None

    # Fuzzy match with category names
    match_result_category = process.extractOne(skill_lower, tool_categories, scorer=fuzz.WRatio)
    category_match, category_score = match_result_category[:2] if match_result_category else (None, 0)

    # Decide based on best score
    if tool_score >= threshold and (tool_score > category_score):
        print(f"🔁 '{skill}' matched to tool '{tool_match}' → category '{tool_category}' (score: {tool_score})")
        return tool_category
    elif category_score >= threshold:
        print(f"🔁 '{skill}' matched directly to category '{category_match}' (score: {category_score})")
        return category_match

    # No good match
    return None



# Main Matching Function
def match_skills_esco_fuzzy(user_skills, threshold): 
    """
    Matches user-entered skills with job roles using NLP + fuzzy matching.
    Filters jobs that have at least 2 matched skills.
    """

    matched_skills = set()

    # Preprocess user input skills
    user_skills = [preprocess_text(skill) for skill in user_skills]

    # Ensure all_skills only contains valid skills
    cleaned_skills = set(skill for skill in all_skills if isinstance(skill, str) and skill.strip())

    # Perform fuzzy matching for each user skill
    for skill in user_skills:
        print(f"\n🔍 Matching User Skill: {skill}")

        # ✅ Exact match logic for single-character user skills (e.g., "r")
        if len(skill.strip()) == 1:
            exact_matches = [s for s in cleaned_skills if s.strip().lower() == skill.strip().lower()]
            if exact_matches:
                matched_skills.add(exact_matches[0])
                print(f"✅ Exact Match for Short Skill: {exact_matches[0]}")
            else:
                print("❌ No exact match found for short skill.")
            continue  # Skip fuzzy matching for this skill

        # Tool match
        tool_raw = map_skills_to_matched_tools(skill, threshold=threshold)
        tool_match = preprocess_text(tool_raw) if tool_raw else None
        tool_match_result = process.extractOne(tool_match, cleaned_skills, scorer=fuzz.WRatio) if tool_match else None
        tool_best, tool_score = tool_match_result[:2] if tool_match_result else (None, 0)
        print(f"Found Tool Match (Tech Tool): {tool_best} with score: {tool_score}")
        # Fuzzy match top 5
        top_matches = process.extract(skill, cleaned_skills, scorer=fuzz.WRatio, limit=5)
        print("Top Matches:")
        for i, (match, score, _) in enumerate(top_matches, start=1):
            print(f"  {i}. {match} ({round(score, 1)})")

        # ✅ Match all top skills with the same max score above threshold
        if tool_best and tool_score >= threshold and tool_score > top_matches[0][1]:
            print(f"✅ Selected Tool Match (Tech Tool): {tool_best}")
            matched_skills.add(tool_best)
        elif top_matches:
            max_score = top_matches[0][1]
            if max_score >= threshold:
                for match, score, _ in top_matches:
                    if score == max_score:
                        # ✅ Prevent single-letter *matched* skills unless perfect match
                        if len(match.strip()) == 1 and score < 100:
                            print(f"⚠️ Skipped short matched skill '{match}' (score: {score}) — not an exact match.")
                            continue
                        matched_skills.add(match)
                        print(f"✅ Selected Tie Match: {match} ({round(score, 1)})")
            elif tool_best and tool_score >= threshold:
                matched_skills.add(tool_best)
                print(f"✅ Selected Tool Match (Tech Tool): {tool_best}")
        else:
            print("❌ No good match found.")

    return matched_skills

# %%
def match_skills_job(matched_skills):

    matched_skills = set(skill.lower().strip() for skill in matched_skills)

    if not matched_skills:
        print("\n🚫 No valid matches found.")
        return pd.DataFrame(columns=["Job Role", "Matched Skills Count"])


    # Step 1: Create 'All Skills' column per job
    esco_taxonomy_df["All Skills"] = (
        esco_taxonomy_df["Essential Skill"].fillna("").astype(str) + ", " +
        esco_taxonomy_df["Essential Knowledge"].fillna("").astype(str) + ", " +
        esco_taxonomy_df["Optional Skill"].fillna("").astype(str) + ", " +
        esco_taxonomy_df["Optional Knowledge"].fillna("").astype(str)
    )

    # Step 2: Group by Job and create a set of lowercase skill strings
    job_skills_df = (
        esco_taxonomy_df.groupby(["Job Role", "Job Description"])["All Skills"]
        .apply(lambda skills: set(s.strip().lower() for line in skills for s in line.split(",") if s.strip()))
        .reset_index(name="All Skills Set")
    )

    # Step 3: Count how many matched skills appear in each job
    job_skills_df["Matched Skills Count"] = job_skills_df["All Skills Set"].apply(
        lambda skills: len(matched_skills.intersection(skills))
    )

    # Step 4: Filter and sort
    matched_jobs = job_skills_df[job_skills_df["Matched Skills Count"] > 1].copy()
    matched_jobs = matched_jobs.sort_values(by="Matched Skills Count", ascending=False)
   
    # Step 5: Merge back in Alternative Titles using Job Role
    alt_titles_df = esco_taxonomy_df[["Job Role", "Alternative Titles"]].drop_duplicates()
    matched_jobs = matched_jobs.merge(alt_titles_df, on="Job Role", how="left")

    # Step 6: Display results
    print("\n📋 Matched Jobs (At Least 2 Skills Matched):")
    print("-" * 90)
    print("| {:<35} | {:<20} | {:<30} |".format("Job Role", "Matched Skills Count", "Alternative Titles"))
    print("-" * 90)
    for _, row in matched_jobs.iterrows():
        print("| {:<35} | {:<20} | {:<30} |".format(
            row["Job Role"], row["Matched Skills Count"], row["Alternative Titles"][:30] if row["Alternative Titles"] else "N/A"
        ))
    print("-" * 90)

    return matched_jobs[["Job Role", "Matched Skills Count", "Alternative Titles"]]

# %%
cybersecurity_analyst_skills =  ["Troubleshooting",
        "Windows OS",
        "Active Directory",
        "Ticketing systems (e.g., ServiceNow)",
        "Customer service",
        "Networking basics",
        "Software installation",
        "Remote desktop support",
        "Antivirus tools",
        "Hardware configuration"]

found_skills = match_skills_esco_fuzzy(cybersecurity_analyst_skills, threshold=85)

match_skills_job(found_skills)
# Out:
# 🔍 Matching User Skill: troubleshoot
# Found Tool Match (Tech Tool): None with score: 0
# Top Matches:
#   1. troubleshoot (100.0)
#   2. perform ict troubleshoot (90.0)
#   3. troubleshoot website (90.0)
#   4. ruby (67.5)
#   5. less (67.5)
# ✅ Selected Tie Match: troubleshoot (100.0)
#
# 🔍 Matching User Skill: window os
# Found Tool Match (Tech Tool): None with score: 0
# Top Matches:
#   1. window phone (76.2)
#   2. cs (60.0)
#   3. io (57.0)
#   4. inform safety standard (52.9)
#   5. swift (51.4)
#
# 🔍 Matching User Skill: active directory
# Found Tool Match (Tech Tool): None with score: 0
# Top Matches:
#   1. distribute directory information service (85.5)
#   2. track key performance indicator (60.0)
#   3. ruby (60.0)
#   4. execute ict user research activity (60.0)
#   5. coordinate technological activity (60.0)
# ✅ Selected Tie Match: distribute directory information service (85.5)
#
# 🔍 Matching User Skill: ticket system (e.g., servicenow)
# 🔁 'ticket system (e.g., servicenow)' matched to tool 'servicenow' → category 'help desk incident management software' (score: 90.0)
# Found Tool Match (Tech Tool): software framework with score: 85.5
# Top Matches:
#   1. deploy ict system (85.5)
#   2. maintain ict system (85.5)
#   3. system think (85.5)
#   4. use ict ticket system (85.5)
#   5. system theory (85.5)
# ✅ Selected Tie Match: deploy ict system (85.5)
# ✅ Selected Tie Match: maintain ict system (85.5)
# ✅ Selected Tie Match: system think (85.5)
# ✅ Selected Tie Match: use ict ticket system (85.5)
# ✅ Selected Tie Match: system theory (85.5)
#
# 🔍 Matching User Skill: customer service
# 🔁 'customer service' matched directly to category 'financial commodity service software' (score: 85.5)
# Found Tool Match (Tech Tool): software framework with score: 85.5
# Top Matches:
#   1. blockchain-based service regulation (85.5)
#   2. collect customer feedback application (85.5)
#   3. identify customer requirement (85.5)
#   4. sql server integration service (85.5)
#   5. use customer relationship management software (85.5)
# ✅ Selected Tie Match: blockchain-based service regulation (85.5)
# ✅ Selected Tie Match: collect customer feedback application (85.5)
# ✅ Selected Tie Match: identify customer requirement (85.5)
# ✅ Selected Tie Match: sql server integration service (85.5)
# ✅ Selected Tie Match: use customer relationship management software (85.5)
#
# 🔍 Matching User Skill: network basic
# 🔁 'network basic' matched directly to category 'network monitor software' (score: 85.5)
# Found Tool Match (Tech Tool): author software with score: 85.5
# Top Matches:
#   1. ict network security risk (85.5)
#   2. network management system tool (85.5)
#   3. analyse network bandwidth requirement (85.5)
#   4. ict network cable limitation (85.5)
#   5. maintain information network hardware (85.5)
# ✅ Selected Tie Match: ict network security risk (85.5)
# ✅ Selected Tie Match: network management system tool (85.5)
# ✅ Selected Tie Match: analyse network bandwidth requirement (85.5)
# ✅ Selected Tie Match: ict network cable limitation (85.5)
# ✅ Selected Tie Match: maintain information network hardware (85.5)
#
# 🔍 Matching User Skill: software installation
# 🔁 'software installation' matched directly to category 'financial commodity service software' (score: 85.5)
# Found Tool Match (Tech Tool): software framework with score: 85.5
# Top Matches:
#   1. statistical analysis system software (85.5)
#   2. use customer relationship management software (85.5)
#   3. provide software test documentation (85.5)
#   4. replicate customer software issue (85.5)
#   5. utilise computer-aided software engineer tool (85.5)
# ✅ Selected Tie Match: statistical analysis system software (85.5)
# ✅ Selected Tie Match: use customer relationship management software (85.5)
# ✅ Selected Tie Match: provide software test documentation (85.5)
# ✅ Selected Tie Match: replicate customer software issue (85.5)
# ✅ Selected Tie Match: utilise computer-aided software engineer tool (85.5)
#
# 🔍 Matching User Skill: remote desktop support
# 🔁 'remote desktop support' matched directly to category 'business intelligence decision support software' (score: 85.5)
# Found Tool Match (Tech Tool): business intelligence with score: 90.0
# Top Matches:
#   1. provide ict support (63.4)
#   2. decision support system (63.3)
#   3. utilise decision support system (60.9)
#   4. puppet (60.0)
#   5. php (60.0)
# ✅ Selected Tool Match (Tech Tool): business intelligence
#
# 🔍 Matching User Skill: antivirus tool
# 🔁 'antivirus tool' matched directly to category 'computer-aided software engineer tool' (score: 85.5)
# Found Tool Match (Tech Tool): utilise computer-aided software engineer tool with score: 95.0
# Top Matches:
#   1. penetration test tool (85.5)
#   2. transformation load tool (85.5)
#   3. network management system tool (85.5)
#   4. utilise computer-aided software engineer tool (85.5)
#   5. database development tool (85.5)
# ✅ Selected Tool Match (Tech Tool): utilise computer-aided software engineer tool
#
# 🔍 Matching User Skill: hardware configuration
# 🔁 'hardware configuration' matched directly to category 'configuration management software' (score: 85.5)
# Found Tool Match (Tech Tool): tool software configuration management with score: 95.0
# Top Matches:
#   1. maintain internet protocol configuration (85.5)
#   2. maintain information network hardware (85.5)
#   3. tool software configuration management (85.5)
#   4. project configuration management (70.6)
#   5. hardware component (65.0)
# ✅ Selected Tool Match (Tech Tool): tool software configuration management
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | embedded system designer            | 4                    | embedded software developer, e |
# | industrial mobile devices software developer | 4                    | handheld software developer, i |
# | ICT application developer           | 4                    | application software developer |
# | software developer                  | 4                    | application developer, applica |
# | software architect                  | 4                    | software architects, software  |
# | mobile application developer        | 4                    | app developer, mobile app spec |
# | ICT technician                      | 4                    | ICT technicians, IT engineer,  |
# | ICT network administrator           | 4                    | network administrators, networ |
# | ICT network architect               | 4                    | network designer, network arch |
# | ICT network technician              | 4                    | network technician, network en |
# | ICT system developer                | 4                    | ICT system developers, ICT sys |
# | database integrator                 | 3                    | data base integrators, data ba |
# | database developer                  | 3                    | database developers, data base |
# | embedded systems software developer | 3                    | embedded systems designer, emb |
# | ICT application configurator        | 3                    | software application configura |
# | ICT system tester                   | 3                    | ICT systems test engineer, ICT |
# | web developer                       | 3                    | web programmer, web applicatio |
# | integration engineer                | 3                    | software integration engineer, |
# | ICT change and configuration manager | 3                    | configuration manager, applica |
# | system configurator                 | 3                    | system setup professional, sys |
# | ICT network engineer                | 3                    | network configurator, networks |
# | digital games tester                | 2                    | digital game tester, virtual g |
# | knowledge engineer                  | 2                    | taxonomist, knowledge engineer |
# | software tester                     | 2                    | application software tester, u |
# | embedded systems security engineer  | 2                    | cybersecurity engineer, cyber  |
# | user interface developer            | 2                    | front end developer, UI progra |
# | ICT accessibility tester            | 2                    | accessibility testers, accessi |
# | digital games developer             | 2                    | digital game developer, comput |
# | blockchain developer                | 2                    | blockchain development enginee |
# | ICT usability tester                | 2                    | user-friendliness tester, usab |
# | ICT security manager                | 2                    | security coordinator, ICT secu |
# | ICT quality assurance manager       | 2                    | ICT quality manager, ICT test  |
# | ICT intelligent systems designer    | 2                    | AI system designer, linked dat |
# | ICT integration tester              | 2                    | compatibility tester, IT compa |
# | ICT help desk manager               | 2                    | ICT help desk managers, IT hel |
# | ICT help desk agent                 | 2                    | IT help desk advisor, ICT serv |
# | ICT disaster recovery analyst       | 2                    | ICT resilience analysts, busin |
# | ICT capacity planner                | 2                    | ICT performance manager, ICT c |
# | ICT business analyst                | 2                    | ICT business analysts, busines |
# | ICT test analyst                    | 2                    | IT test analyst, test designer |
# ------------------------------------------------------------------------------------------
#                                         Job Role  Matched Skills Count  \
# 0                       embedded system designer                     4
# 1   industrial mobile devices software developer                     4
# 2                      ICT application developer                     4
# 3                             software developer                     4
# 4                             software architect                     4
# 5                   mobile application developer                     4
# 6                                 ICT technician                     4
# 7                      ICT network administrator                     4
# 8                          ICT network architect                     4
# 9                         ICT network technician                     4
# 10                          ICT system developer                     4
# 11                           database integrator                     3
# 12                            database developer                     3
# 13           embedded systems software developer                     3
# 14                  ICT application configurator                     3
# 15                             ICT system tester                     3
# 16                                 web developer                     3
# 17                          integration engineer                     3
# 18          ICT change and configuration manager                     3
# 19                           system configurator                     3
# 20                          ICT network engineer                     3
# 21                          digital games tester                     2
# 22                            knowledge engineer                     2
# 23                               software tester                     2
# 24            embedded systems security engineer                     2
# 25                      user interface developer                     2
# 26                      ICT accessibility tester                     2
# 27                       digital games developer                     2
# 28                          blockchain developer                     2
# 29                          ICT usability tester                     2
# 30                          ICT security manager                     2
# 31                 ICT quality assurance manager                     2
# 32              ICT intelligent systems designer                     2
# 33                        ICT integration tester                     2
# 34                         ICT help desk manager                     2
# 35                           ICT help desk agent                     2
# 36                 ICT disaster recovery analyst                     2
# 37                          ICT capacity planner                     2
# 38                          ICT business analyst                     2
# 39                              ICT test analyst                     2
#
#                                    Alternative Titles
# 0   embedded software developer, embedded systems ...
# 1   handheld software developer, industrial mobile...
# 2   application software developers, application d...
# 3   application developer, application programmer,...
# 4   software architects, software designer, applic...
# 5   app developer, mobile app specialist, mobile a...
# 6   ICT technicians, IT engineer, computer operato...
# 7   network administrators, network support, netwo...
# 8                network designer, network architects
# 9   network technician, network engineer, network ...
# 10  ICT system developers, ICT systems developer, ...
# 11  data base integrators, data base integrator, d...
# 12  database developers, data base developer, data...
# 13  embedded systems designer, embedded systems so...
# 14  software application configurator, app configu...
# 15  ICT systems test engineer, ICT systems testers...
# 16  web programmer, web application developer, web...
# 17  software integration engineer, ICT integration...
# 18  configuration manager, application lifecycle m...
# 19  system setup professional, system configuratio...
# 20  network configurator, networks engineer, netwo...
# 21  digital game tester, virtual games tester, dig...
# 22  taxonomist, knowledge engineers, linked data e...
# 23  application software tester, unit tester, appl...
# 24  cybersecurity engineer, cyber security enginee...
# 25  front end developer, UI programmer, user inter...
# 26  accessibility testers, accessibility test spec...
# 27  digital game developer, computer games develop...
# 28  blockchain development engineer, blockchain en...
# 29  user-friendliness tester, usability developer,...
# 30  security coordinator, ICT security managers, I...
# 31  ICT quality manager, ICT test manager, IT qual...
# 32  AI system designer, linked data engineer, inte...
# 33  compatibility tester, IT compatibility tester,...
# 34  ICT help desk managers, IT helpdesk manager, I...
# 35  IT help desk advisor, ICT service desk agent, ...
# 36  ICT resilience analysts, business continuity s...
# 37  ICT performance manager, ICT capacity planners...
# 38  ICT business analysts, business process specia...
# 39                     IT test analyst, test designer

# %% [markdown]
# This code defines a two-step pipeline for matching user-provided skills to the ESCO skills taxonomy using sentence embeddings and cosine similarity. The prepare_esco_embeddings() function takes a raw set of ESCO skills, cleans it by removing empty strings and extra whitespace, and then uses the pre-trained Sentence-BERT model (all-MiniLM-L6-v2) to encode the cleaned skills into numerical embeddings. These embeddings represent the semantic meaning of each skill in vector space. The match_user_skills() function then preprocesses the user's input skills (e.g., lowercasing, stripping whitespace), encodes them using the same SBERT model, and compares them to the ESCO embeddings using cosine similarity. For each user skill, it identifies the top matching ESCO skill(s) and returns the results in a DataFrame showing the original user skill, the closest matched ESCO skill, and their similarity score. This approach enables semantic matching even when the exact phrasing of skills differs.

# %%
def prepare_skill_embeddings(raw_skills):
    """
    Cleans and encodes a set of ESCO skills using SBERT.
    Returns the cleaned skill list, model, and embeddings.
    """
    model = SentenceTransformer('all-MiniLM-L6-v2')

    # Case 1: Dictionary input
    if isinstance(raw_skills, dict):
        items = [
            k.strip() for k in raw_skills.keys()
            if isinstance(k, str) and k.strip() != ''
        ]
        embeddings = model.encode(items)
        return items, model, embeddings, raw_skills

    # Case 2: List or set input
    elif isinstance(raw_skills, (list, set)):
        items = [
            s.strip() for s in raw_skills
            if isinstance(s, str) and s.strip() != ''
        ]
        embeddings = model.encode(items)
        return items, model, embeddings, None

    else:
        raise TypeError("Input must be a list, set, or dictionary.")


def match_user_skills(user_skills, skills, embeddings, model, threshold=0.7, top_k=1):
    """
    Matches user-entered skills to a set of reference skills using cosine similarity.
    Returns a nicely printed DataFrame of best matches and the matched skills list.
    """
    matched_skills = []
    user_skills = [preprocess_text(skill) for skill in user_skills]
    user_embeddings = model.encode(user_skills)

    records = []

    for i, user_emb in enumerate(user_embeddings):
        sims = cosine_similarity([user_emb], embeddings)[0]
        top_indices = sims.argsort()[::-1][:top_k]

        best_match_idx = top_indices[0]
        best_score = round(float(sims[best_match_idx]),3)

        if best_score >= threshold:
            matched_skill = skills[best_match_idx]
            matched_skills.append(matched_skill)
        else:
            matched_skill = "No Match"

        records.append({
            "User Skill": user_skills[i],
            "Matched Skill": matched_skill,
            "Cosine Similarity": best_score
        })

    df = pd.DataFrame(records)

    # ✅ Pretty print
    print("\n📋 Skill Matching Results")
    print("-" * 60)
    print(df.to_markdown(index=False))
    print("-" * 60)

    return matched_skills

# %%
esco_skills, esco_model, esco_embeddings, _ = prepare_skill_embeddings(all_skills)

anzsco_skills, anzsco_model, anzsco_embeddings, anzsco_lookup  = prepare_skill_embeddings(tool_to_category)

# %%
skills = [
        "Requirements gathering",
        "Process mapping",
        "Stakeholder communication",
        "SQL",
        "UML diagrams",
        "Agile/Scrum",
        "Microsoft Excel",
        "Jira or Confluence",
        "Data analysis",
        "Technical documentation"
    ]
esco_matches = match_user_skills(skills, esco_skills, esco_embeddings, esco_model, 0.7)

anzsco_tool_matches = match_user_skills(skills, anzsco_skills, anzsco_embeddings, anzsco_model, 0.7)

tools_found_list = []
for tool in anzsco_tool_matches:
    tools_found_list.append(tool_to_category[tool])

esco_tool_matches = match_user_skills(tools_found_list, esco_skills, esco_embeddings, esco_model, 0.7)

combined_matches = esco_tool_matches + esco_matches

print_pretty_table(match_skills_job(combined_matches))
# Out:
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                | Matched Skill                    |   Cosine Similarity |
# |:--------------------------|:---------------------------------|--------------------:|
# | requirement gather        | interact user gather requirement |               0.7   |
# | process map               | No Match                         |               0.681 |
# | stakeholder communication | No Match                         |               0.493 |
# | sql                       | sql server                       |               0.736 |
# | uml diagram               | No Match                         |               0.552 |
# | agile/scrum               | agile development                |               0.856 |
# | microsoft excel           | No Match                         |               0.548 |
# | jira confluence           | No Match                         |               0.343 |
# | data analysis             | perform data analysis            |               0.838 |
# | technical documentation   | use technical documentation      |               0.926 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                | Matched Skill   |   Cosine Similarity |
# |:--------------------------|:----------------|--------------------:|
# | requirement gather        | No Match        |               0.459 |
# | process map               | No Match        |               0.528 |
# | stakeholder communication | No Match        |               0.279 |
# | sql                       | No Match        |               0.687 |
# | uml diagram               | No Match        |               0.34  |
# | agile/scrum               | No Match        |               0.346 |
# | microsoft excel           | No Match        |               0.507 |
# | jira confluence           | atlassian jira  |               0.738 |
# | data analysis             | No Match        |               0.554 |
# | technical documentation   | No Match        |               0.455 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                  | Matched Skill      |   Cosine Similarity |
# |:----------------------------|:-------------------|--------------------:|
# | project management software | project management |                0.86 |
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | data warehouse designer             | 2                    | data warehouse architect, data |
# | database designer                   | 2                    | data architect, database desig |
# | numerical tool and process control programmer | 2                    | numerical process control oper |
# | software analyst                    | 2                    | application analyst, programmi |
# | user interface designer             | 2                    | accessibility designer, user i |
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role                                      |   Matched Skills Count | Alternative Titles                                                                                                                                                                                                                                                                                                                                                                                                               |
# |-----------------------------------------------|------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | data warehouse designer                       |                      2 | data warehouse architect, data warehouse developer                                                                                                                                                                                                                                                                                                                                                                               |
# | database designer                             |                      2 | data architect, database designers, data base designers, database architect, data base designer, database design engineer, data model designer                                                                                                                                                                                                                                                                                   |
# | numerical tool and process control programmer |                      2 | numerical process control operator, numerical tool programmer, numerical process control tool setting operator, numerical tool maker, numerical tool setting operator, numerical process control  set up operator, numerical process control programmer, numerical tool machine set up operator, numerical tool machine operator, numerical process control supervisor, numerical tool l programme setter, numerical tool setter |
# | software analyst                              |                      2 | application analyst, programming analyst, programmer analyst, software analysts, software requirement analyst, software requirements analyst, analyst of software                                                                                                                                                                                                                                                                |
# | user interface designer                       |                      2 | accessibility designer, user interface designers, UI designer                                                                                                                                                                                                                                                                                                                                                                    |

# %% [markdown]
# Testing Algorithm

# %%
it_job_skills = { 
    "Software Developer": [
        "Java",
        "Python",
        "Git",
        "Agile methodology",
        "RESTful APIs",
        "Object-oriented programming (OOP)",
        "SQL",
        "Unit testing",
        "Debugging",
        "Continuous Integration/Continuous Deployment (CI/CD)"
    ],
    "Data Analyst": [
        "SQL",
        "Microsoft Excel",
        "Power BI",
        "Tableau",
        "Python (Pandas, NumPy)",
        "Data cleaning",
        "Statistical analysis",
        "Data visualization",
        "A/B testing",
        "Business acumen"
    ],
    "Cybersecurity Analyst": [
        "Network security",
        "SIEM (e.g., Splunk)",
        "Threat analysis",
        "Vulnerability assessment",
        "Firewalls and intrusion detection systems",
        "Risk assessment",
        "Incident response",
        "Encryption techniques",
        "Security policies",
        "Linux"
    ],
    "Cloud Engineer": [
        "AWS",
        "Microsoft Azure",
        "Google Cloud Platform (GCP)",
        "Terraform",
        "Docker",
        "Kubernetes",
        "Linux system administration",
        "Scripting (Python, Bash)",
        "Cloud security",
        "Monitoring (e.g., CloudWatch, Prometheus)"
    ],
    "DevOps Engineer": [
        "CI/CD pipelines",
        "Jenkins",
        "Docker",
        "Kubernetes",
        "Linux",
        "Git",
        "Infrastructure as Code (IaC)",
        "Monitoring/logging (e.g., ELK stack)",
        "Cloud platforms (AWS, Azure)",
        "Automation scripting"
    ],
    "Machine Learning Engineer": [
        "Python",
        "Scikit-learn",
        "TensorFlow or PyTorch",
        "Data preprocessing",
        "Feature engineering",
        "Model evaluation",
        "Machine learning algorithms",
        "Git",
        "Cloud ML platforms",
        "Statistics"
    ],
    "Business Analyst (IT)": [
        "Requirements gathering",
        "Process mapping",
        "Stakeholder communication",
        "SQL",
        "UML diagrams",
        "Agile/Scrum",
        "Microsoft Excel",
        "Jira or Confluence",
        "Data analysis",
        "Technical documentation"
    ],
    "Web Developer": [
        "HTML",
        "CSS",
        "JavaScript",
        "React.js",
        "Node.js",
        "REST APIs",
        "Git",
        "Responsive design",
        "Browser debugging",
        "Web performance optimization"
    ],
    "Database Administrator": [
        "SQL",
        "Oracle or MySQL",
        "Backup and recovery",
        "Performance tuning",
        "Database security",
        "Stored procedures",
        "Indexing",
        "Data migration",
        "Monitoring tools",
        "Scripting (e.g., Bash, Python)"
    ],
    "IT Support Specialist": [
        "Troubleshooting",
        "Windows OS",
        "Active Directory",
        "Ticketing systems (e.g., ServiceNow)",
        "Customer service",
        "Networking basics",
        "Software installation",
        "Remote desktop support",
        "Antivirus tools",
        "Hardware configuration"
    ]
}

# Loop through each IT job and its associated skills
for job_title, skills in it_job_skills.items():
    print(f"\n--- Matching for {job_title} ---")

    # Step 1: Match user skills to ESCO and ANZSCO
    esco_matches = match_user_skills(skills, esco_skills, esco_embeddings, esco_model, 0.7)
    anzsco_tool_matches = match_user_skills(skills, anzsco_skills, anzsco_embeddings, anzsco_model, 0.7)

    # Step 2: Extract tools and map to categories
    tools_found_list = []
    for tool in anzsco_tool_matches:
        if tool in tool_to_category:
            tools_found_list.append(tool_to_category[tool])

    # Step 3: Match mapped tools to ESCO
    esco_tool_matches = match_user_skills(tools_found_list, esco_skills, esco_embeddings, esco_model, 0.7)

    # Step 4: Combine all ESCO matches
    combined_matches = esco_tool_matches + esco_matches

    # Step 5: Print the results
    print_pretty_table(match_skills_job(combined_matches))
# Out:
# --- Matching for Software Developer ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                                           | Matched Skill               |   Cosine Similarity |
# |:-----------------------------------------------------|:----------------------------|--------------------:|
# | java                                                 | java                        |               1     |
# | python                                               | python                      |               1     |
# | git                                                  | No Match                    |               0.616 |
# | agile methodology                                    | agile development           |               0.858 |
# | restful apis                                         | No Match                    |               0.401 |
# | object-oriented program (oop)                        | use object-oriented program |               0.906 |
# | sql                                                  | sql server                  |               0.736 |
# | unit test                                            | perform software unit test  |               0.728 |
# | debug                                                | debug software              |               0.799 |
# | continuous integration/continuous deployment (ci/cd) | No Match                    |               0.525 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                                           | Matched Skill   |   Cosine Similarity |
# |:-----------------------------------------------------|:----------------|--------------------:|
# | java                                                 | No Match        |               0.507 |
# | python                                               | python          |               1     |
# | git                                                  | git             |               1     |
# | agile methodology                                    | No Match        |               0.318 |
# | restful apis                                         | No Match        |               0.404 |
# | object-oriented program (oop)                        | No Match        |               0.467 |
# | sql                                                  | No Match        |               0.687 |
# | unit test                                            | No Match        |               0.445 |
# | debug                                                | debug software  |               0.799 |
# | continuous integration/continuous deployment (ci/cd) | No Match        |               0.372 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                                   | Matched Skill                   |   Cosine Similarity |
# |:---------------------------------------------|:--------------------------------|--------------------:|
# | software development program language        | smart contract program language |               0.739 |
# | document management code versioning software | No Match                        |               0.535 |
# | application load test software               | No Match                        |               0.626 |
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | ICT application configurator        | 4                    | software application configura |
# | ICT system developer                | 4                    | ICT system developers, ICT sys |
# | industrial mobile devices software developer | 4                    | handheld software developer, i |
# | embedded systems software developer | 4                    | embedded systems designer, emb |
# | ICT application developer           | 4                    | application software developer |
# | digital games developer             | 4                    | digital game developer, comput |
# | software developer                  | 4                    | application developer, applica |
# | software tester                     | 4                    | application software tester, u |
# | mobile application developer        | 4                    | app developer, mobile app spec |
# | ICT network engineer                | 4                    | network configurator, networks |
# | user interface developer            | 4                    | front end developer, UI progra |
# | web developer                       | 4                    | web programmer, web applicatio |
# | system configurator                 | 3                    | system setup professional, sys |
# | blockchain developer                | 3                    | blockchain development enginee |
# | ICT system architect                | 3                    | ICT systems architect, solutio |
# | data warehouse designer             | 3                    | data warehouse architect, data |
# | database designer                   | 3                    | data architect, database desig |
# | database developer                  | 3                    | database developers, data base |
# | user interface designer             | 3                    | accessibility designer, user i |
# | enterprise architect                | 3                    | enterprise developer, enterpri |
# | software analyst                    | 3                    | application analyst, programmi |
# | cloud engineer                      | 3                    | hybrid cloud engineer, cloud i |
# | numerical tool and process control programmer | 2                    | numerical process control oper |
# | telecommunications engineering technician | 2                    | telecommunications administrat |
# | software architect                  | 2                    | software architects, software  |
# | embedded system designer            | 2                    | embedded software developer, e |
# | knowledge engineer                  | 2                    | taxonomist, knowledge engineer |
# | integration engineer                | 2                    | software integration engineer, |
# | computer vision engineer            | 2                    | computer vision applied scient |
# | chief ICT security officer          | 2                    | fead of IT security, chief inf |
# | ICT technician                      | 2                    | ICT technicians, IT engineer,  |
# | ICT system analyst                  | 2                    | IT system analyst, IT systems  |
# | ICT security technician             | 2                    | ICT security technicians, IT s |
# | ICT network administrator           | 2                    | network administrators, networ |
# | ICT intelligent systems designer    | 2                    | AI system designer, linked dat |
# | webmaster                           | 2                    | web technician, webmasters, e- |
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role                                      |   Matched Skills Count | Alternative Titles                                                                                                                                                                                                                                                                                                                                                                                                               |
# |-----------------------------------------------|------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | ICT application configurator                  |                      4 | software application configurator, app configurator, application configurators, application software configurator                                                                                                                                                                                                                                                                                                                |
# | ICT system developer                          |                      4 | ICT system developers, ICT systems developer, systems programmer, system developer, component developer, system software developer, chief ICT system developer, ICT systems developers, IT system developer, systems developer                                                                                                                                                                                                   |
# | industrial mobile devices software developer  |                      4 | handheld software developer, industrial mobile devices software programmer, industrial mobile devices software coder, handheld programmer                                                                                                                                                                                                                                                                                        |
# | embedded systems software developer           |                      4 | embedded systems designer, embedded systems software developers, embedded software developerl embedded systems engineer, embedded system software programmer, embedded system software developer, embedded software programmer                                                                                                                                                                                                   |
# | ICT application developer                     |                      4 | application software developers, application developer, application software engineer, application designer, app software developer, software programmer                                                                                                                                                                                                                                                                         |
# | digital games developer                       |                      4 | digital game developer, computer games developer, virtual games developer, video games developer, games programmer, digital games developers                                                                                                                                                                                                                                                                                     |
# | software developer                            |                      4 | application developer, application programmer, solutions developer, programmer, software specialist, application software developer, software developers, software engineer, applications engineer, soft developer, developer of software                                                                                                                                                                                        |
# | software tester                               |                      4 | application software tester, unit tester, application tester, software application tester, tester, module tester, software testers, software testing specialist, soft tester                                                                                                                                                                                                                                                     |
# | mobile application developer                  |                      4 | app developer, mobile app specialist, mobile app developer, mobile application developers, app programmer, app coder                                                                                                                                                                                                                                                                                                             |
# | ICT network engineer                          |                      4 | network configurator, networks engineer, networks developer, network developer, networks designer, network engineers                                                                                                                                                                                                                                                                                                             |
# | user interface developer                      |                      4 | front end developer, UI programmer, user interface developers, UI developers, UI developer, user interface engineer                                                                                                                                                                                                                                                                                                              |
# | web developer                                 |                      4 | web programmer, web application developer, web engineer, web developers, web specialist                                                                                                                                                                                                                                                                                                                                          |
# | system configurator                           |                      3 | system setup professional, system configuration professional, IT system configurator, ICT system configurator, systems configurator, system configurators                                                                                                                                                                                                                                                                        |
# | blockchain developer                          |                      3 | blockchain development engineer, blockchain engineer, decentralized ledger technology specialist, DLT engineer, DLT specialist                                                                                                                                                                                                                                                                                                   |
# | ICT system architect                          |                      3 | ICT systems architect, solution architect, IT systems architect, IT system architect, systems architect, ICT system architects, ICT systems architects, information systems architect                                                                                                                                                                                                                                            |
# | data warehouse designer                       |                      3 | data warehouse architect, data warehouse developer                                                                                                                                                                                                                                                                                                                                                                               |
# | database designer                             |                      3 | data architect, database designers, data base designers, database architect, data base designer, database design engineer, data model designer                                                                                                                                                                                                                                                                                   |
# | database developer                            |                      3 | database developers, data base developer, data base developers, database development engineer, database coder, database design specialist, database programmer                                                                                                                                                                                                                                                                   |
# | user interface designer                       |                      3 | accessibility designer, user interface designers, UI designer                                                                                                                                                                                                                                                                                                                                                                    |
# | enterprise architect                          |                      3 | enterprise developer, enterprise architects, enterprise architecture manager, enterprise designer                                                                                                                                                                                                                                                                                                                                |
# | software analyst                              |                      3 | application analyst, programming analyst, programmer analyst, software analysts, software requirement analyst, software requirements analyst, analyst of software                                                                                                                                                                                                                                                                |
# | cloud engineer                                |                      3 | hybrid cloud engineer, cloud infrastructure engineer, cloud software engineer, cloud computing engineer, cloud network engineer, cloud solution engineer, cloud security engineer, cloud architect, cloud devops engineer, cloud-native engineer, cloud developer                                                                                                                                                                |
# | numerical tool and process control programmer |                      2 | numerical process control operator, numerical tool programmer, numerical process control tool setting operator, numerical tool maker, numerical tool setting operator, numerical process control  set up operator, numerical process control programmer, numerical tool machine set up operator, numerical tool machine operator, numerical process control supervisor, numerical tool l programme setter, numerical tool setter |
# | telecommunications engineering technician     |                      2 | telecommunications administrator, telecommunication administrator, telecommunications administrators, telecom administrator, communication administrator, communications administrator, telecoms administrator                                                                                                                                                                                                                   |
# | software architect                            |                      2 | software architects, software designer, application architect                                                                                                                                                                                                                                                                                                                                                                    |
# | embedded system designer                      |                      2 | embedded software developer, embedded systems designers, embedded systems developer, embedded systems programmer, embedded system programmer, embedded system developer                                                                                                                                                                                                                                                          |
# | knowledge engineer                            |                      2 | taxonomist, knowledge engineers, linked data engineer, knowledge officer, information engineer                                                                                                                                                                                                                                                                                                                                   |
# | integration engineer                          |                      2 | software integration engineer, ICT integration engineers, IT integration engineer, system integration engineer                                                                                                                                                                                                                                                                                                                   |
# | computer vision engineer                      |                      2 | computer vision applied scientist, computer vision expert, computer vision project engineer, computer vision specialist, smart technics computer vision engineer                                                                                                                                                                                                                                                                 |
# | chief ICT security officer                    |                      2 | fead of IT security, chief information security officer, chief ICT security officers, head IT security officer, CISO                                                                                                                                                                                                                                                                                                             |
# | ICT technician                                |                      2 | ICT technicians, IT engineer, computer operator, IT technician, ICT engineer                                                                                                                                                                                                                                                                                                                                                     |
# | ICT system analyst                            |                      2 | IT system analyst, IT systems analyst, network analyst, ICT systems analysts, ICT system analysts, systems analyst, system analyst, ICT systems analyst                                                                                                                                                                                                                                                                          |
# | ICT security technician                       |                      2 | ICT security technicians, IT security officer, IT security technician, ICT security officer                                                                                                                                                                                                                                                                                                                                      |
# | ICT network administrator                     |                      2 | network administrators, network support, network manager, network specialist, networks administrator                                                                                                                                                                                                                                                                                                                             |
# | ICT intelligent systems designer              |                      2 | AI system designer, linked data engineer, intelligent systems developer, semantic technologies engineer, designer of intelligent systems, machine learning systems designer, intelligent systems engineer, intelligent system designer, intelligent systems designers, artificial intelligence designer                                                                                                                          |
# | webmaster                                     |                      2 | web technician, webmasters, e-commerce technician, web administrator, website administrator                                                                                                                                                                                                                                                                                                                                      |
#
# --- Matching for Data Analyst ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill             | Matched Skill                        |   Cosine Similarity |
# |:-----------------------|:-------------------------------------|--------------------:|
# | sql                    | sql server                           |               0.736 |
# | microsoft excel        | No Match                             |               0.548 |
# | power bi               | No Match                             |               0.369 |
# | tableau                | No Match                             |               0.382 |
# | python (pandas, numpy) | No Match                             |               0.513 |
# | data clean             | perform data cleanse                 |               0.843 |
# | statistical analysis   | apply statistical analysis technique |               0.717 |
# | data visualization     | No Match                             |               0.56  |
# | a/b test               | No Match                             |               0.373 |
# | business acumen        | apply business acumen                |               0.803 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill             | Matched Skill      |   Cosine Similarity |
# |:-----------------------|:-------------------|--------------------:|
# | sql                    | No Match           |               0.687 |
# | microsoft excel        | No Match           |               0.507 |
# | power bi               | microsoft power bi |               0.835 |
# | tableau                | tableau            |               1     |
# | python (pandas, numpy) | No Match           |               0.513 |
# | data clean             | No Match           |               0.428 |
# | statistical analysis   | No Match           |               0.649 |
# | data visualization     | No Match           |               0.501 |
# | a/b test               | No Match           |               0.306 |
# | business acumen        | No Match           |               0.475 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                                      | Matched Skill                        |   Cosine Similarity |
# |:------------------------------------------------|:-------------------------------------|--------------------:|
# | business intelligence decision support software | business intelligence                |               0.762 |
# | statistical data analysis software              | statistical analysis system software |               0.939 |
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | data analyst                        | 3                    | data warehousing analyst, data |
# | database integrator                 | 3                    | data base integrators, data ba |
# | computer scientist                  | 2                    | ICT scientist, computer scient |
# | computer vision engineer            | 2                    | computer vision applied scient |
# | data scientist                      | 2                    | data scientists, data engineer |
# | database administrator              | 2                    | database manager, DBA, databas |
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role                 |   Matched Skills Count | Alternative Titles                                                                                                                                                                                                 |
# |--------------------------|------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | data analyst             |                      3 | data warehousing analyst, data analysts, data warehouse analyst, data storage analyst                                                                                                                              |
# | database integrator      |                      3 | data base integrators, data base integrator, database integrators, data integrator, database development specialist                                                                                                |
# | computer scientist       |                      2 | ICT scientist, computer scientist, IT researcher, ICT science researcher, computers scientist, ICT research scientist, IT research scientist, IT science researcher, ICT researcher, ICT researchers, IT scientist |
# | computer vision engineer |                      2 | computer vision applied scientist, computer vision expert, computer vision project engineer, computer vision specialist, smart technics computer vision engineer                                                   |
# | data scientist           |                      2 | data scientists, data engineer, research data scientist, data expert, data research scientist                                                                                                                      |
# | database administrator   |                      2 | database manager, DBA, database administrators, data manager, data administrator, database configurator, data base administrator, data base administrators                                                         |
#
# --- Matching for Cybersecurity Analyst ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                          | Matched Skill                             |   Cosine Similarity |
# |:------------------------------------|:------------------------------------------|--------------------:|
# | network security                    | ict network security risk                 |               0.711 |
# | siem (e.g., splunk)                 | No Match                                  |               0.379 |
# | threat analysis                     | No Match                                  |               0.559 |
# | vulnerability assessment            | perform security vulnerability assessment |               0.922 |
# | firewall intrusion detection system | No Match                                  |               0.58  |
# | risk assessment                     | perform risk analysis                     |               0.813 |
# | incident response                   | No Match                                  |               0.673 |
# | encryption technique                | No Match                                  |               0.659 |
# | security policy                     | define security policy                    |               0.865 |
# | linux                               | No Match                                  |               0.594 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                          | Matched Skill   |   Cosine Similarity |
# |:------------------------------------|:----------------|--------------------:|
# | network security                    | No Match        |               0.49  |
# | siem (e.g., splunk)                 | splunk siem     |               0.864 |
# | threat analysis                     | No Match        |               0.507 |
# | vulnerability assessment            | No Match        |               0.449 |
# | firewall intrusion detection system | No Match        |               0.684 |
# | risk assessment                     | No Match        |               0.646 |
# | incident response                   | No Match        |               0.622 |
# | encryption technique                | No Match        |               0.32  |
# | security policy                     | No Match        |               0.456 |
# | linux                               | No Match        |               0.522 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill               | Matched Skill                  |   Cosine Similarity |
# |:-------------------------|:-------------------------------|--------------------:|
# | network monitor software | network management system tool |               0.726 |
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | ICT disaster recovery analyst       | 3                    | ICT resilience analysts, busin |
# | ICT network technician              | 3                    | network technician, network en |
# | ICT resilience manager              | 3                    | manager for disaster recovery, |
# | embedded systems security engineer  | 3                    | cybersecurity engineer, cyber  |
# | ethical hacker                      | 3                    | vulnerability analyst, ethical |
# | ICT network administrator           | 2                    | network administrators, networ |
# | ICT network architect               | 2                    | network designer, network arch |
# | ICT security consultant             | 2                    | IT security expert, ICT securi |
# | ICT security manager                | 2                    | security coordinator, ICT secu |
# | IT auditor                          | 2                    | ICT auditor, IT Quality Apprai |
# | digital forensics expert            | 2                    | information forensics expert,  |
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role                           |   Matched Skills Count | Alternative Titles                                                                                                                                                                                                                                            |
# |------------------------------------|------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | ICT disaster recovery analyst      |                      3 | ICT resilience analysts, business continuity strategist, business continuity analyst, IT resilience analyst, IT disaster recovery analyst, disaster recovery officer                                                                                          |
# | ICT network technician             |                      3 | network technician, network engineer, network maintenance professional, networks technician, network technicians, IT network technician, assistant network administrator, system engineer                                                                     |
# | ICT resilience manager             |                      3 | manager for disaster recovery, manager for vulnerability, manager for IT resilience, IT resilience manager, ICT resilience managers, vulnerability manager, disaster recovery manager                                                                         |
# | embedded systems security engineer |                      3 | cybersecurity engineer, cyber security engineer, embedded systems security expert, internet of thing security engineer, IoT security engineer                                                                                                                 |
# | ethical hacker                     |                      3 | vulnerability analyst, ethical hackers, ICT security tester, system security tester, network security tester                                                                                                                                                  |
# | ICT network administrator          |                      2 | network administrators, network support, network manager, network specialist, networks administrator                                                                                                                                                          |
# | ICT network architect              |                      2 | network designer, network architects                                                                                                                                                                                                                          |
# | ICT security consultant            |                      2 | IT security expert, ICT security advisor, information communications technology security consultant, ICT security consultants, IT security advisor, IT security consultant, consultant in ICT security activities, information technology security consultant |
# | ICT security manager               |                      2 | security coordinator, ICT security managers, ICT technical security expert, information security manager, IT security manager, ICT security chief, IT security chief                                                                                          |
# | IT auditor                         |                      2 | ICT auditor, IT Quality Appraiser, information technology auditor                                                                                                                                                                                             |
# | digital forensics expert           |                      2 | information forensics expert, cyber forensics expert, digital forensics specialist, digital forensics experts, digital forensic expert, ICT forensics expert, computer forensics investigator, digital forensics analyst, computer forensics expert           |
#
# --- Matching for Cloud Engineer ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                             | Matched Skill             |   Cosine Similarity |
# |:---------------------------------------|:--------------------------|--------------------:|
# | aws                                    | No Match                  |               0.452 |
# | microsoft azure                        | No Match                  |               0.479 |
# | google cloud platform (gcp)            | No Match                  |               0.547 |
# | terraform                              | No Match                  |               0.437 |
# | docker                                 | No Match                  |               0.359 |
# | kubernetes                             | No Match                  |               0.382 |
# | linux system administration            | No Match                  |               0.571 |
# | script (python, bash)                  | No Match                  |               0.665 |
# | cloud security                         | cloud security compliance |               0.821 |
# | monitor (e.g., cloudwatch, prometheus) | No Match                  |               0.634 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                             | Matched Skill   |   Cosine Similarity |
# |:---------------------------------------|:----------------|--------------------:|
# | aws                                    | aws             |               1     |
# | microsoft azure                        | azure           |               0.961 |
# | google cloud platform (gcp)            | No Match        |               0.627 |
# | terraform                              | No Match        |               0.481 |
# | docker                                 | No Match        |               0.419 |
# | kubernetes                             | kubernetes      |               1     |
# | linux system administration            | No Match        |               0.522 |
# | script (python, bash)                  | No Match        |               0.665 |
# | cloud security                         | No Match        |               0.544 |
# | monitor (e.g., cloudwatch, prometheus) | No Match        |               0.584 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                           | Matched Skill                          |   Cosine Similarity |
# |:-------------------------------------|:---------------------------------------|--------------------:|
# | cloud compute infrastructure service | develop cloud service                  |               0.708 |
# | cloud compute infrastructure service | develop cloud service                  |               0.708 |
# | configuration management software    | tool software configuration management |               0.805 |
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | cloud DevOps engineer               | 2                    | cloud automation engineer, clo |
# | cloud architect                     | 2                    | aws cloud architect, cloud sol |
# | cloud engineer                      | 2                    | hybrid cloud engineer, cloud i |
# | cloud identity manager              | 2                    | cloud identity access manager, |
# | cloud software developer            | 2                    | cloud administrator, cloud and |
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role                 |   Matched Skills Count | Alternative Titles                                                                                                                                                                                                                                                                                   |
# |--------------------------|------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | cloud DevOps engineer    |                      2 | cloud automation engineer, cloud devops, cloud devops solution specialist, cloud infrastructure devops engineer, devops, devops administrator, devops analyst, devops architect, devops consultant, devops consultant engineer, devops engineer, devops specialist, site reliability devops engineer |
# | cloud architect          |                      2 | aws cloud architect, cloud solutions consultant                                                                                                                                                                                                                                                      |
# | cloud engineer           |                      2 | hybrid cloud engineer, cloud infrastructure engineer, cloud software engineer, cloud computing engineer, cloud network engineer, cloud solution engineer, cloud security engineer, cloud architect, cloud devops engineer, cloud-native engineer, cloud developer                                    |
# | cloud identity manager   |                      2 | cloud identity access manager, cloud identity engineer,  cloud identity risk manager                                                                                                                                                                                                                 |
# | cloud software developer |                      2 | cloud administrator, cloud and infrastructure specialist, cloud consultant, cloud deployment specialist, cloud infrastructure it specialist, cloud solutions specialist, cloud technical specialist, full stack cloud software engineer                                                              |
#
# --- Matching for DevOps Engineer ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                           | Matched Skill      |   Cosine Similarity |
# |:-------------------------------------|:-------------------|--------------------:|
# | ci/cd pipeline                       | No Match           |               0.44  |
# | jenkins                              | jenkins            |               1     |
# | docker                               | No Match           |               0.359 |
# | kubernetes                           | No Match           |               0.382 |
# ...
#
# --- Matching for Web Developer ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                   | Matched Skill              |   Cosine Similarity |
# |:-----------------------------|:---------------------------|--------------------:|
# | html                         | No Match                   |               0.54  |
# | cs                           | cs                         |               1     |
# | javascript                   | javascript                 |               1     |
# | react.js                     | No Match                   |               0.465 |
# | node.js                      | No Match                   |               0.617 |
# | rest apis                    | No Match                   |               0.4   |
# | git                          | No Match                   |               0.616 |
# | responsive design            | maintain responsive design |               0.892 |
# | browser debug                | No Match                   |               0.63  |
# | web performance optimization | No Match                   |               0.585 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                   | Matched Skill   |   Cosine Similarity |
# |:-----------------------------|:----------------|--------------------:|
# | html                         | No Match        |               0.493 |
# | cs                           | No Match        |               0.563 |
# | javascript                   | No Match        |               0.376 |
# | react.js                     | No Match        |               0.305 |
# | node.js                      | No Match        |               0.383 |
# | rest apis                    | No Match        |               0.367 |
# | git                          | git             |               1     |
# | responsive design            | No Match        |               0.357 |
# | browser debug                | No Match        |               0.63  |
# | web performance optimization | No Match        |               0.43  |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                                   | Matched Skill   |   Cosine Similarity |
# |:---------------------------------------------|:----------------|--------------------:|
# | document management code versioning software | No Match        |               0.535 |
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | webmaster                           | 3                    | web technician, webmasters, e- |
# | user interface developer            | 2                    | front end developer, UI progra |
# | web content manager                 | 2                    | web content specialist, digita |
# | web developer                       | 2                    | web programmer, web applicatio |
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role                 |   Matched Skills Count | Alternative Titles                                                                                                                      |
# |--------------------------|------------------------|-----------------------------------------------------------------------------------------------------------------------------------------|
# | webmaster                |                      3 | web technician, webmasters, e-commerce technician, web administrator, website administrator                                             |
# | user interface developer |                      2 | front end developer, UI programmer, user interface developers, UI developers, UI developer, user interface engineer                     |
# | web content manager      |                      2 | web content specialist, digital content, web content curatorspecialist, web content administrators, content curator, content specialist |
# | web developer            |                      2 | web programmer, web application developer, web engineer, web developers, web specialist                                                 |
#
# --- Matching for Database Administrator ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                  | Matched Skill              |   Cosine Similarity |
# |:----------------------------|:---------------------------|--------------------:|
# | sql                         | sql server                 |               0.736 |
# | oracle mysql                | mysql                      |               0.714 |
# | backup recovery             | perform backup             |               0.731 |
# | performance tune            | No Match                   |               0.506 |
# | database security           | maintain database security |               0.91  |
# | store procedure             | No Match                   |               0.521 |
# | index                       | No Match                   |               0.368 |
# | data migration              | migrate exist data         |               0.747 |
# | monitor tool                | No Match                   |               0.655 |
# | script (e.g., bash, python) | No Match                   |               0.674 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                  | Matched Skill   |   Cosine Similarity |
# |:----------------------------|:----------------|--------------------:|
# | sql                         | No Match        |               0.687 |
# | oracle mysql                | mysql           |               0.714 |
# | backup recovery             | No Match        |               0.281 |
# | performance tune            | No Match        |               0.552 |
# | database security           | No Match        |               0.493 |
# | store procedure             | No Match        |               0.405 |
# | index                       | No Match        |               0.525 |
# | data migration              | No Match        |               0.574 |
# | monitor tool                | No Match        |               0.676 |
# | script (e.g., bash, python) | No Match        |               0.617 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                   | Matched Skill              |   Cosine Similarity |
# |:-----------------------------|:---------------------------|--------------------:|
# | database management software | database management system |               0.908 |
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# | data centre operator                | 5                    | data center administrator, dat |
# | database administrator              | 5                    | database manager, DBA, databas |
# | data warehouse designer             | 4                    | data warehouse architect, data |
# | database designer                   | 4                    | data architect, database desig |
# | database developer                  | 4                    | database developers, data base |
# | system configurator                 | 4                    | system setup professional, sys |
# | database integrator                 | 3                    | data base integrators, data ba |
# | ICT security administrator          | 2                    | network security administrator |
# | ICT system administrator            | 2                    | enterprise administrator, IT s |
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role                   |   Matched Skills Count | Alternative Titles                                                                                                                                                                                                                                                                                                     |
# |----------------------------|------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | data centre operator       |                      5 | data center administrator, data centre operators, data centre employee                                                                                                                                                                                                                                                 |
# | database administrator     |                      5 | database manager, DBA, database administrators, data manager, data administrator, database configurator, data base administrator, data base administrators                                                                                                                                                             |
# | data warehouse designer    |                      4 | data warehouse architect, data warehouse developer                                                                                                                                                                                                                                                                     |
# | database designer          |                      4 | data architect, database designers, data base designers, database architect, data base designer, database design engineer, data model designer                                                                                                                                                                         |
# | database developer         |                      4 | database developers, data base developer, data base developers, database development engineer, database coder, database design specialist, database programmer                                                                                                                                                         |
# | system configurator        |                      4 | system setup professional, system configuration professional, IT system configurator, ICT system configurator, systems configurator, system configurators                                                                                                                                                              |
# | database integrator        |                      3 | data base integrators, data base integrator, database integrators, data integrator, database development specialist                                                                                                                                                                                                    |
# | ICT security administrator |                      2 | network security administrator, system security administrator, ICT security administrators, IT security administrator                                                                                                                                                                                                  |
# | ICT system administrator   |                      2 | enterprise administrator, IT system administrator, ICT systems administrator, ICT sysadmins, IT systems administrator, ICT sysadmin, ICT systems administrators, system and network administrator, server administrator, system and networks administrator, network administrator, ICT system administrators, sysadmin |
#
# --- Matching for IT Support Specialist ---
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                       | Matched Skill         |   Cosine Similarity |
# |:---------------------------------|:----------------------|--------------------:|
# | troubleshoot                     | troubleshoot          |               1     |
# | window os                        | No Match              |               0.632 |
# | active directory                 | No Match              |               0.522 |
# | ticket system (e.g., servicenow) | No Match              |               0.68  |
# | customer service                 | communicate customer  |               0.706 |
# | network basic                    | No Match              |               0.601 |
# | software installation            | No Match              |               0.553 |
# | remote desktop support           | No Match              |               0.374 |
# | antivirus tool                   | No Match              |               0.417 |
# | hardware configuration           | hardware architecture |               0.713 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
# | User Skill                       | Matched Skill   |   Cosine Similarity |
# |:---------------------------------|:----------------|--------------------:|
# | troubleshoot                     | No Match        |               0.439 |
# | window os                        | No Match        |               0.45  |
# | active directory                 | No Match        |               0.538 |
# | ticket system (e.g., servicenow) | No Match        |               0.527 |
# | customer service                 | No Match        |               0.613 |
# | network basic                    | No Match        |               0.477 |
# | software installation            | No Match        |               0.637 |
# | remote desktop support           | No Match        |               0.41  |
# | antivirus tool                   | No Match        |               0.593 |
# | hardware configuration           | No Match        |               0.367 |
# ------------------------------------------------------------
#
# 📋 Skill Matching Results
# ------------------------------------------------------------
#
# ------------------------------------------------------------
#
# 📋 Matched Jobs (At Least 2 Skills Matched):
# ------------------------------------------------------------------------------------------
# | Job Role                            | Matched Skills Count | Alternative Titles             |
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
#
# 📋 Matched Jobs with Alternative Titles
# | Job Role   | Matched Skills Count   | Alternative Titles   |
# |------------|------------------------|----------------------|
